# %% [markdown]
# <a href="https://colab.research.google.com/github/shevank/What-Does-1GB-of-Mobile-Data-Cost-by-Country-/blob/main/ejercicio_visualizaci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
data = "/content/drive/MyDrive/Data Science 2022/Cost of 1GB of Data.xlsx"
import pandas as pd 
df = pd.read_excel(data)
df
# Out:
#      Rank     Country  Avg Price of 1GB (USD)
# 0       1       India                    0.09
# 1       2      Israel                    0.11
# 2       3  Kyrgyzstan                    0.21
# 3       4       Italy                    0.43
# 4       5     Ukraine                    0.46
# ..    ...         ...                     ...
# 150   151    Botswana                   13.87
# 151   152       Yemen                   15.98
# 152   153        Chad                   23.33
# 153   154       Benin                   27.22
# 154   155      Malawi                   27.41
#
# [155 rows x 3 columns]

# %%
df.describe()
# Out:
#              Rank  Avg Price of 1GB (USD)
# count  155.000000              155.000000
# mean    78.000000                3.748452
# std     44.888751                4.500110
# min      1.000000                0.090000
# 25%     39.500000                1.050000
# 50%     78.000000                2.220000
# 75%    116.500000                4.540000
# max    155.000000               27.410000

# %%
menor_45 = df['Avg Price of 1GB (USD)'] < 4.5
df[menor_45]
# Out:
#      Rank        Country  Avg Price of 1GB (USD)
# 0       1          India                    0.09
# 1       2         Israel                    0.11
# 2       3     Kyrgyzstan                    0.21
# 3       4          Italy                    0.43
# 4       5        Ukraine                    0.46
# ..    ...            ...                     ...
# 110   111  Guinea-Bissau                    4.12
# 111   112           Mali                    4.12
# 112   113        Lao PDR                    4.16
# 113   114           Iraq                    4.20
# 114   115   South Africa                    4.30
#
# [115 rows x 3 columns]

# %%
menor_45 = df['Avg Price of 1GB (USD)'] < 4.5
mayor_45 = ~menor_45 
mayor_45
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 150     True
# 151     True
# 152     True
# 153     True
# 154     True
# Name: Avg Price of 1GB (USD), Length: 155, dtype: bool

# %%
df[mayor_45].groupby(['Country'])[['Avg Price of 1GB (USD)']].sum()
# Out:
#                           Avg Price of 1GB (USD)
# Country
# Angola                                      5.29
# Belgium                                     4.88
# Benin                                      27.22
# Bolivia                                     5.09
# Botswana                                   13.87
# Canada                                     12.55
# Central African Republic                    8.25
# Chad                                       23.33
# Cuba                                       13.33
# Cyprus                                     13.56
# Czech Republic                              7.95
# Equatorial Guinea                          12.78
# Eswatini                                   13.31
# Gabon                                       4.89
# Gambia                                      5.10
# Greece                                     12.06
# Hungary                                     5.32
# Libya                                       4.73
# ...

# %%
import matplotlib.pyplot as plt
from numpy import arange
from numpy.random import randint

# %%
fig1 = plt.figure(dpi=150)
ax1 = fig1.add_subplot(111)

num = 10
x = df['Country'].head(10)
#print(x)

ya = randint(df['Avg Price of 1GB (USD)'].head(10),num) 
yb = randint(df['Avg Price of 1GB (USD)'].head(10),num)
#print(ya, yb)

sep = 0.3

#barras - parametro 1: valores de x; parametro 2: valores en y; parametro 3: ancho de barra.
#print(x, ya, yb)
ax1.bar(x, ya, sep, color='lightblue')
#ax1.plot(x, ya, 'gD--', color='green')
#ax1.bar(x+sep, yb, sep, color='darkblue')
plt.xticks(rotation = 90);
#ax1.set_xticks(x+sep) #posición de etiquetas en x

ax1.set_xticklabels(df['Country']) #nombre de etiquetas en x

plt.show()
